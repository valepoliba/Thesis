# %%
from pydoc import importfile
import rdflib
import random
import pandas as pd
from sklearn.cluster import KMeans
import os

from rdflib import ConjunctiveGraph
import gc, copy, datetime

import os, sys
p = os.path.abspath('..')
sys.path.insert(1, p)

from knowledge_graph import *

from rdf2vec import RDF2VecTransformer

from lcs_rdf_graph_test import LCS

from rdf_graph_utils import rdf_to_plot, rdf_to_text, pred_obj_significant, compare_prev_next_iteration, different_predicates_count, diff_pred_significant


def rdflib_to_kg_nquads(rdflib_g, label_predicates=[]):
    # Iterate over quads, add s, p and o to graph and 2 edges (s-->p, p-->o)
    # all predicates in label_predicates get excluded
    print(rdflib_g)
    kg = KnowledgeGraph()
    for s, p, o, _ in rdflib_g.quads((None, None, None, None)):
        if p not in label_predicates:
            s_v, o_v = Vertex(str(s)), Vertex(str(o))
            p_v = Vertex(str(p), predicate=True)
            kg.add_vertex(s_v)
            kg.add_vertex(p_v)
            kg.add_vertex(o_v)
            kg.add_edge(s_v, p_v)
            kg.add_edge(p_v, o_v)

    return kg


def get_drug_name(graph, drug):
    query = """
               SELECT ?obj
               WHERE { ?s <http://www.w3.org/2000/01/rdf-schema#label> ?obj.
               """.replace("?s", "<%s>" % drug) + "}"

    query_res = graph.query(query)
    label = []
    for res in query_res:
        label.append(str(res.obj))

    return label

# %%
print(end='Loading data... ', flush=True)
g = ConjunctiveGraph()

g.parse('../../datasets/drugbank/drugbank.nq', format="nquads")
print('OK')
#
# # Extract all database drugs' URI
all_drugs_file = pd.read_csv('../../datasets/drugbank/all_drugs.tsv', sep='\t')
all_drugs = [rdflib.URIRef(x) for x in all_drugs_file['drug']]
#
# # Define irrelevant predicates
bad_predicates = pd.read_csv('../../datasets/drugbank/bad_predicates.tsv', sep='\t')
bad_predicates = [rdflib.URIRef(x) for x in bad_predicates['bad_predicates']]
#
# # Define relevant predicates
with open('../../datasets/drugbank/good_predicates.tsv', 'r') as good_predicates:
    gp = good_predicates.read().split()
#

stop_patterns = pd.read_csv('../../datasets/drugbank/stop_patterns.tsv', sep='\t')
stop_patterns = [x for x in stop_patterns['stopping_patterns']]

preds = pd.read_csv('../../datasets/drugbank/uninformative.tsv', sep='\t')
preds = [rdflib.URIRef(x) for x in preds['uninformative']]
# Out:
# Loading data... OK

# %%
kg = rdflib_to_kg_nquads(g, label_predicates=bad_predicates)

# del g
# gc.collect()

#
# # %%
# # estraggo un'istanza di knowledge graph per ogni drug presente in quello iniziale

kg_depth = 4

i = 0
j = 0

kv = []
drugs = []
graphs = []

for drug in all_drugs:
    try:
        gi = extract_instance(kg, drug, kg_depth)
        graphs.append(gi)
        drugs.append(drug)
        kv.append({'graph': gi, 'resource': drug})
        i += 1
    except Exception as e:
        j += 1

print('ok:' + str(i))
print('not imported: ' + str(j))

del kg
gc.collect()
# Out:
# [a rdflib:ConjunctiveGraph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']]
# ok:7754
# not imported: 5
# 0

# %%
# # Embeddings
transformer = RDF2VecTransformer(wl=False, max_path_depth=4, vector_size=15, walks_per_graph=1)
# transformer = RDF2VecTransformer()
transformer.fit(graphs, drugs)
embeddings = transformer.transform(graphs, drugs)
# Out:
# 7754it [00:07, 1015.10it/s]
# Extracted 7754 walks for 7754 instances!
# Starting Word2Vec Model
# Word2Vec Ended
# Transform.

# %%
# STAMPO PER OGNI RISORSA IL CLUSTER A CUI CORRISPONDE, IN MODO DA POTERNE PRELEVARE PER IL MOMENTO
# DUE APPARTENENTI ALLO STESSO CLUSTER
kmeans = KMeans(n_clusters=250)
km = kmeans.fit(embeddings)
y_kmeans = kmeans.predict(embeddings)

print("clustering models created")
# Out:
# clustering models created

# %%
from pathlib import Path


clusters = {i: [] for i in range(kmeans.n_clusters)}
i = 0
for j in y_kmeans:
    clusters[j].append(i)
    i += 1

# Save clusters obtained from kmeans
file = open("../../datasets/drugbank/clusters_log/lcs_first_second_lv_evaluation/kmeans_125_" + str(datetime.datetime.now()).replace(":", "."), "a")
file.write(str(clusters))
file.close()

# %%
# Print clusters and their dimension

for key in clusters.keys():
    print("cluster " + str(key) + " with dimension: " + str(len(clusters[key])))
# Out:
# cluster 0 with dimension: 33
# cluster 1 with dimension: 29
# cluster 2 with dimension: 30
# cluster 3 with dimension: 36
# cluster 4 with dimension: 9
# cluster 5 with dimension: 40
# cluster 6 with dimension: 41
# cluster 7 with dimension: 36
# cluster 8 with dimension: 21
# cluster 9 with dimension: 21
# cluster 10 with dimension: 22
# cluster 11 with dimension: 39
# cluster 12 with dimension: 39
# cluster 13 with dimension: 53
# cluster 14 with dimension: 29
# cluster 15 with dimension: 19
# cluster 16 with dimension: 34
# cluster 17 with dimension: 48
# cluster 18 with dimension: 18
# cluster 19 with dimension: 18
# cluster 20 with dimension: 29
# cluster 21 with dimension: 20
# cluster 22 with dimension: 43
# cluster 23 with dimension: 30
# cluster 24 with dimension: 29
# cluster 25 with dimension: 11
# cluster 26 with dimension: 33
# cluster 27 with dimension: 41
# cluster 28 with dimension: 23
# cluster 29 with dimension: 26
# cluster 30 with dimension: 31
# cluster 31 with dimension: 37
# cluster 32 with dimension: 40
# cluster 33 with dimension: 12
# cluster 34 with dimension: 26
# cluster 35 with dimension: 26
# cluster 36 with dimension: 34
# cluster 37 with dimension: 42
# cluster 38 with dimension: 28
# cluster 39 with dimension: 41
# cluster 40 with dimension: 18
# cluster 41 with dimension: 32
# cluster 42 with dimension: 45
# cluster 43 with dimension: 47
# cluster 44 with dimension: 30
# cluster 45 with dimension: 31
# cluster 46 with dimension: 33
# cluster 47 with dimension: 42
# cluster 48 with dimension: 9
# cluster 49 with dimension: 34
# cluster 50 with dimension: 32
# cluster 51 with dimension: 23
# cluster 52 with dimension: 36
# cluster 53 with dimension: 30
# cluster 54 with dimension: 36
# cluster 55 with dimension: 41
# cluster 56 with dimension: 24
# cluster 57 with dimension: 24
# cluster 58 with dimension: 37
# cluster 59 with dimension: 31
# cluster 60 with dimension: 28
# cluster 61 with dimension: 15
# cluster 62 with dimension: 40
# cluster 63 with dimension: 33
# cluster 64 with dimension: 40
# cluster 65 with dimension: 41
# cluster 66 with dimension: 26
# cluster 67 with dimension: 38
# cluster 68 with dimension: 32
# cluster 69 with dimension: 30
# cluster 70 with dimension: 43
# cluster 71 with dimension: 37
# cluster 72 with dimension: 19
# cluster 73 with dimension: 16
# cluster 74 with dimension: 36
# cluster 75 with dimension: 34
# cluster 76 with dimension: 26
# cluster 77 with dimension: 21
# cluster 78 with dimension: 36
# cluster 79 with dimension: 22
# cluster 80 with dimension: 28
# cluster 81 with dimension: 12
# cluster 82 with dimension: 29
# cluster 83 with dimension: 35
# cluster 84 with dimension: 40
# cluster 85 with dimension: 36
# cluster 86 with dimension: 40
# cluster 87 with dimension: 31
# cluster 88 with dimension: 25
# cluster 89 with dimension: 45
# cluster 90 with dimension: 24
# cluster 91 with dimension: 25
# cluster 92 with dimension: 21
# cluster 93 with dimension: 16
# cluster 94 with dimension: 45
# cluster 95 with dimension: 47
# cluster 96 with dimension: 25
# cluster 97 with dimension: 36
# cluster 98 with dimension: 33
# cluster 99 with dimension: 18
# cluster 100 with dimension: 36
# cluster 101 with dimension: 26
# cluster 102 with dimension: 34
# cluster 103 with dimension: 33
# cluster 104 with dimension: 54
# cluster 105 with dimension: 28
# cluster 106 with dimension: 33
# cluster 107 with dimension: 44
# cluster 108 with dimension: 27
# cluster 109 with dimension: 27
# cluster 110 with dimension: 36
# cluster 111 with dimension: 25
# cluster 112 with dimension: 43
# cluster 113 with dimension: 16
# cluster 114 with dimension: 43
# cluster 115 with dimension: 41
# cluster 116 with dimension: 40
# cluster 117 with dimension: 26
# cluster 118 with dimension: 23
# cluster 119 with dimension: 25
# cluster 120 with dimension: 37
# cluster 121 with dimension: 30
# cluster 122 with dimension: 22
# cluster 123 with dimension: 32
# cluster 124 with dimension: 15
# cluster 125 with dimension: 37
# cluster 126 with dimension: 25
# cluster 127 with dimension: 33
# cluster 128 with dimension: 19
# cluster 129 with dimension: 42
# cluster 130 with dimension: 44
# cluster 131 with dimension: 36
# cluster 132 with dimension: 38
# cluster 133 with dimension: 36
# cluster 134 with dimension: 38
# cluster 135 with dimension: 39
# cluster 136 with dimension: 34
# cluster 137 with dimension: 30
# cluster 138 with dimension: 34
# cluster 139 with dimension: 34
# cluster 140 with dimension: 23
# cluster 141 with dimension: 18
# cluster 142 with dimension: 37
# cluster 143 with dimension: 30
# cluster 144 with dimension: 40
# cluster 145 with dimension: 31
# cluster 146 with dimension: 33
# cluster 147 with dimension: 26
# cluster 148 with dimension: 32
# cluster 149 with dimension: 21
# cluster 150 with dimension: 48
# cluster 151 with dimension: 32
# cluster 152 with dimension: 33
# cluster 153 with dimension: 22
# cluster 154 with dimension: 14
# cluster 155 with dimension: 31
# cluster 156 with dimension: 22
# cluster 157 with dimension: 17
# cluster 158 with dimension: 39
# cluster 159 with dimension: 37
# cluster 160 with dimension: 26
# cluster 161 with dimension: 38
# cluster 162 with dimension: 28
# cluster 163 with dimension: 35
# cluster 164 with dimension: 37
# cluster 165 with dimension: 27
# cluster 166 with dimension: 37
# cluster 167 with dimension: 10
# cluster 168 with dimension: 39
# cluster 169 with dimension: 27
# cluster 170 with dimension: 29
# cluster 171 with dimension: 43
# cluster 172 with dimension: 34
# cluster 173 with dimension: 40
# cluster 174 with dimension: 30
# cluster 175 with dimension: 30
# cluster 176 with dimension: 29
# cluster 177 with dimension: 21
# cluster 178 with dimension: 25
# cluster 179 with dimension: 45
# cluster 180 with dimension: 17
# cluster 181 with dimension: 14
# cluster 182 with dimension: 38
# cluster 183 with dimension: 10
# cluster 184 with dimension: 41
# cluster 185 with dimension: 43
# cluster 186 with dimension: 41
# cluster 187 with dimension: 29
# cluster 188 with dimension: 39
# cluster 189 with dimension: 33
# cluster 190 with dimension: 8
# cluster 191 with dimension: 28
# cluster 192 with dimension: 28
# cluster 193 with dimension: 57
# cluster 194 with dimension: 40
# cluster 195 with dimension: 27
# cluster 196 with dimension: 26
# cluster 197 with dimension: 20
# cluster 198 with dimension: 30
# cluster 199 with dimension: 38
# cluster 200 with dimension: 45
# cluster 201 with dimension: 36
# cluster 202 with dimension: 38
# cluster 203 with dimension: 29
# cluster 204 with dimension: 34
# cluster 205 with dimension: 24
# cluster 206 with dimension: 10
# cluster 207 with dimension: 12
# cluster 208 with dimension: 33
# cluster 209 with dimension: 35
# cluster 210 with dimension: 32
# cluster 211 with dimension: 36
# cluster 212 with dimension: 25
# cluster 213 with dimension: 29
# cluster 214 with dimension: 34
# cluster 215 with dimension: 28
# cluster 216 with dimension: 23
# cluster 217 with dimension: 26
# cluster 218 with dimension: 39
# cluster 219 with dimension: 30
# cluster 220 with dimension: 27
# cluster 221 with dimension: 39
# cluster 222 with dimension: 33
# cluster 223 with dimension: 47
# cluster 224 with dimension: 42
# cluster 225 with dimension: 41
# cluster 226 with dimension: 39
# cluster 227 with dimension: 39
# cluster 228 with dimension: 23
# cluster 229 with dimension: 33
# cluster 230 with dimension: 26
# cluster 231 with dimension: 19
# cluster 232 with dimension: 38
# cluster 233 with dimension: 36
# cluster 234 with dimension: 10
# cluster 235 with dimension: 39
# cluster 236 with dimension: 40
# cluster 237 with dimension: 32
# cluster 238 with dimension: 40
# cluster 239 with dimension: 22
# cluster 240 with dimension: 41
# cluster 241 with dimension: 28
# cluster 242 with dimension: 22
# cluster 243 with dimension: 21
# cluster 244 with dimension: 28
# cluster 245 with dimension: 20
# cluster 246 with dimension: 27
# cluster 247 with dimension: 32
# cluster 248 with dimension: 32
# cluster 249 with dimension: 26

# %%
directory = "../../outputs/drugbank/lcs_first_second_lv_evaluation/oLast_NQ_NEW_" + str(datetime.datetime.now()).replace(":", ".").replace(" ", "_")
if not os.path.exists(directory):
    os.mkdir(directory)

# cluster da analizzare
# k = 22

# seleziono il cluster con il minor numero di elementi

k = min(clusters.keys(), key=lambda a: len(clusters[a]))

# seleziono il cluster con il minor numero totale di archi

#k = min(clusters.keys(), 
#    key=lambda key: sum(len(kg_to_rdflib(graphs[res], kg_depth)) for res in clusters[key]))

# seleziono il cluster con l'elemento che ha il minor numero di archi

#k = min(clusters.keys(), key=lambda key: min([len(kg_to_rdflib(graphs[res], kg_depth))
#                                                 for res in clusters[key]]))

# k random choice
#k = random.randrange(250)

clusters[k] = sorted(clusters[k],  key=lambda res: len(kg_to_rdflib(graphs[res], kg_depth)))

# clusters[k] = [48, 50]

L = len(clusters[k])

print("esploro il cluster: " + str(k) + " con dimensione " + str(L))
print(clusters[k])
# risorsa iniziale
# resource_1 = random.choice(clusters[k])

resource_1 = clusters[k].pop(0)

graph_1 = graphs[resource_1]

print("risorsa iniziale: " + str(resource_1) + " di dim -> " + str(len(kg_to_rdflib(graph_1, kg_depth))))

# clusters[k].remove(resource_1)
explored_resoures = [resource_1]

iteration = 0
# Out:
# esploro il cluster: 190 con dimensione 8
# [7698, 5346, 3981, 2311, 5392, 231, 1662, 1879]
# risorsa iniziale: 7698 di dim -> 11

# %%
while clusters[k]:
    file = open(directory + "/tmp_LCS.log", "a")
    
    resource_2 = clusters[k].pop(0)
    graph_2 = graphs[resource_2]
    print("LCS with resource: " + str(resource_2) 
          + " con dim: " + str(len(kg_to_rdflib(graph_2, kg_depth))))

    # seed
    seed = LCS(graph_1, graph_2, depth=2, stop_patterns=stop_patterns, uninformative_triples=preds)
    seed.find()
              
    explored_resoures.append(resource_2)
        
    print("dim LCS itermedio tra " + str(explored_resoures) + " \n--> " + str(len(seed)))
        
    del graph_1
    del graph_2
    gc.collect()
        
    graph_1 = copy.deepcopy(seed)

    print("Iterazione: " + str(iteration) + ", trovato LCS tra: " + str(explored_resoures))
    rdf_to_text(seed, directory, "turtle", "tmp_LCS_" + str(iteration))
    rdf_to_text(seed, directory, "nt", "tmp_LCS_" + str(iteration))

    # gestione numero predicato-oggetto significativi
    filecountfirst, filecountsecond = pred_obj_significant(directory, iteration, gp)

    print('Count significant row first level: ', filecountfirst)
    print('Count significant row second level: ', filecountsecond)

    del seed
    gc.collect()
        
    file.write("Iterazione: " + str(iteration) +  " risorse esplorate: " + str(explored_resoures) + "\n")
    file.close()
        
    iteration += 1
# Out:
# LCS with resource: 5346 con dim: 48
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346]
# --> 2
# Iterazione: 0, trovato LCS tra: [7698, 5346]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 3981 con dim: 51
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981]
# --> 2
# Iterazione: 1, trovato LCS tra: [7698, 5346, 3981]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 2311 con dim: 192
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981, 2311]
# --> 2
# Iterazione: 2, trovato LCS tra: [7698, 5346, 3981, 2311]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 5392 con dim: 239
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981, 2311, 5392]
# --> 2
# Iterazione: 3, trovato LCS tra: [7698, 5346, 3981, 2311, 5392]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 231 con dim: 278
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981, 2311, 5392, 231]
# --> 2
# Iterazione: 4, trovato LCS tra: [7698, 5346, 3981, 2311, 5392, 231]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 1662 con dim: 574
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981, 2311, 5392, 231, 1662]
# --> 2
# Iterazione: 5, trovato LCS tra: [7698, 5346, 3981, 2311, 5392, 231, 1662]
# Count significant row first level:  2
# Count significant row second level:  0
# LCS with resource: 1879 con dim: 801
# starting graphs exploration...
# exploration ended.
# filling LCS graph.
# graph completed.
# dim LCS itermedio tra [7698, 5346, 3981, 2311, 5392, 231, 1662, 1879]
# --> 2
# Iterazione: 6, trovato LCS tra: [7698, 5346, 3981, 2311, 5392, 231, 1662, 1879]
# Count significant row first level:  2
# Count significant row second level:  0

# %%
rdf_to_plot(graph_1, directory)
print("LCS finale tra le risorse: " + str(explored_resoures))
# Out:
# #### plotting graph ####
# LCS finale tra le risorse: [7698, 5346, 3981, 2311, 5392, 231, 1662, 1879]

# %%
# SALVATAGGIO DEL GRAFO

rdf_to_text(graph_1, directory, 'turtle', 'final_LCS')
rdf_to_text(graph_1, directory, 'nt', 'final_LCS')
file =  open(directory + "/final_LCS_resources.log", "a")
file.write(str(explored_resoures))
# Out:
# 47

# %%
file.write("\n ####### \n")

explored_resources_names = []

for drug_index in explored_resoures:
    drug_name = get_drug_name(g, drugs[drug_index])
    explored_resources_names.extend(drug_name)

file.write(str(explored_resources_names))
file.close()

del g
gc.collect()
# Out:
# 18688
